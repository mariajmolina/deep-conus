# %%
exec(open('/glade/u/home/molina/python_scripts/deep-conus/deep-conus/09_dlmodel_interpretor.py').read())
# Out:
# Using TensorFlow backend.

# %%
fig = plt.figure(figsize=(6.25,3))

levels=[0,5,10,15,20,25,30,35,40,45,50,55,60,65,70,75,80]
cmap = colortables.get_colortable('NWSReflectivity')


ax1 = fig.add_axes([0.0, 0.0, 0.5, 0.9])

data1=xr.open_dataset(
    '/glade/scratch/molina/DL_proj/future_conus_fields/dl_models/saliency_nomask_model25_random1_tp_99_500_EU3.nc')

ax1.set_title("u 3 km (Neuron 11)", fontsize=12)
ax1.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax1.contour(data1.saliency_maps[10,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax1.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax1.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)


ax2 = fig.add_axes([0.5, 0.0, 0.5, 0.9])

data1=xr.open_dataset(
    '/glade/scratch/molina/DL_proj/future_conus_fields/dl_models/saliency_nomask_model25_random1_tp_99_500_EV3.nc')

ax2.set_title("v 3 km (Neuron 32)", fontsize=12)
cs = ax2.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax2.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax2.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax2.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)


plt.savefig(f"/glade/work/molina/DATA/temp_figs/saliency_tp.png", bbox_inches='tight', dpi=200)
plt.show()

# %%
fig = plt.figure(figsize=(6.25,3))

levels=[0,5,10,15,20,25,30,35,40,45,50,55,60,65,70,75,80]
cmap = colortables.get_colortable('NWSReflectivity')


ax1 = fig.add_axes([0.0, 0.0, 0.5, 0.9])

data1=xr.open_dataset(
    '/glade/scratch/molina/DL_proj/future_conus_fields/dl_models/saliency_nomask_model25_random1_fp_200_EU3.nc')

ax1.set_title("u 3 km (Neuron 32)", fontsize=12)
ax1.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax1.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax1.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax1.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)


ax2 = fig.add_axes([0.5, 0.0, 0.5, 0.9])

data1=xr.open_dataset(
    '/glade/scratch/molina/DL_proj/future_conus_fields/dl_models/saliency_nomask_model25_random1_fp_200_EV3.nc')

ax2.set_title("v 3 km (Neuron 32)", fontsize=12)
ax2.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax2.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax2.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax2.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)


plt.savefig(f"/glade/work/molina/DATA/temp_figs/saliency_fp.png", bbox_inches='tight', dpi=200)
plt.show()

# %%
fig = plt.figure(figsize=(6.25,3))

levels=[0,5,10,15,20,25,30,35,40,45,50,55,60,65,70,75,80]
cmap = colortables.get_colortable('NWSReflectivity')


ax1 = fig.add_axes([0.0, 0.0, 0.5, 0.9])

data1=xr.open_dataset(
    '/glade/scratch/molina/DL_proj/future_conus_fields/dl_models/saliency_nomask_model25_random1_fn_01_100_EU3.nc')

ax1.set_title("u 3 km (Neuron 11)", fontsize=12)
ax1.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax1.contour(data1.saliency_maps[10,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax1.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax1.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)


ax2 = fig.add_axes([0.5, 0.0, 0.5, 0.9])

data1=xr.open_dataset(
    '/glade/scratch/molina/DL_proj/future_conus_fields/dl_models/saliency_nomask_model25_random1_fn_01_100_EV3.nc')

ax2.set_title("v 3 km (Neuron 32)", fontsize=12)
ax2.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax2.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax2.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax2.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)


plt.savefig(f"/glade/work/molina/DATA/temp_figs/saliency_fn.png", bbox_inches='tight', dpi=200)
plt.show()

# %%
fig = plt.figure(figsize=(6.25,3))

levels=[0,5,10,15,20,25,30,35,40,45,50,55,60,65,70,75,80]
cmap = colortables.get_colortable('NWSReflectivity')


ax1 = fig.add_axes([0.0, 0.0, 0.5, 0.9])

data1=xr.open_dataset(
    '/glade/scratch/molina/DL_proj/future_conus_fields/dl_models/saliency_nomask_model25_random1_tn_01_80000_EU3.nc')

ax1.set_title("u 3 km (Neuron 10)", fontsize=12)
ax1.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax1.contour(data1.saliency_maps[9,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax1.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax1.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)


ax2 = fig.add_axes([0.5, 0.0, 0.5, 0.9])

data1=xr.open_dataset(
    '/glade/scratch/molina/DL_proj/future_conus_fields/dl_models/saliency_nomask_model25_random1_tn_01_80000_EV3.nc')

ax2.set_title("v 3 km (Neuron 2)", fontsize=12)
ax2.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax2.contour(data1.saliency_maps[1,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax2.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax2.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)


plt.savefig(f"/glade/work/molina/DATA/temp_figs/saliency_tn.png", bbox_inches='tight', dpi=200)
plt.show()
