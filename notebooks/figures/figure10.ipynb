# %% [markdown]
# ### Figure 10 (Molina, Gagne, and Prein; under review)
#
# Fig 10. Saliency maps for representative example future climate thunderstorms, includ-ing true positive (a-d), false positive (e-h), false negative (i-l), and true negative (m-p) cases.Variables shown include several denoted as important by the permutation feature importanceanalysis, such 3 km zonal (a,e,i,m) and meridional (b,f,j,n) winds, and water vapor mixing ratio(qw) at 5 km (d,h,l,p).  Mixing ratio (qw) at 1 km is also shown (c,g,k,o).
#
# **Figure by Maria J. Molina (NCAR)**

# %%
from scipy.ndimage import gaussian_filter
import xarray as xr
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib.pyplot import cm
from metpy.plots import colortables
import matplotlib.colors as colors
from configpaths import future_dl_models, figsave_path, current_dl_models, future_dl_preprocess

# %%
# %--------------------------------------------------------

import matplotlib.patheffects as path_effects
levels=[0,5,10,15,20,25,30,35,40,45,50,55,60,65,70,75,80]
cmap = colortables.get_colortable('NWSReflectivity')

#create a transparent and filled-color colobar for use later. will not plot here.
import matplotlib as mpl
data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tp_99_245_EU3.nc')
my_cmap_rgb = cmap(np.arange(16))
alpha = 0.2
for i in range(3): # Do not include the last column!
    my_cmap_rgb[:,i] = (1 - alpha) + alpha*my_cmap_rgb[:,i]
my_cmap = mpl.colors.ListedColormap(my_cmap_rgb, name='my_cmap')
cs_t = plt.contourf(data1.dbz, cmap=my_cmap, levels=levels)
cs = plt.contourf(data1.saliency_maps[10,:,:], 
                   [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
plt.close()

# %--------------------------------------------------------
# Out:
# /glade/work/molina/miniconda3/envs/python-tutorial/lib/python3.7/site-packages/ipykernel_launcher.py:17: UserWarning: linewidths is ignored by contourf

# %%
# %--------------------------------------------------------

fig = plt.figure(figsize=(9.,10.))

# %--------------------------------------------------------

ax1 = fig.add_axes([0.0, 0.75, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tp_99_245_EU3.nc')

ax1.set_title("a) u 3 km (Neuron 21)", fontsize=12)
ax1.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax1.contour(data1.saliency_maps[20,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax1.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax1.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

ax1.set_ylabel("Hit", fontsize=12)

# %--------------------------------------------------------

ax2 = fig.add_axes([0.25, 0.75, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tp_99_245_EV3.nc')

ax2.set_title("b) v 3 km (Neuron 15)", fontsize=12)
ax2.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax2.contour(data1.saliency_maps[14,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax2.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax2.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax3 = fig.add_axes([0.5, 0.75, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tp_99_245_QVAPOR1.nc')

ax3.set_title("c) q$_{w}$ 1 km (Neuron 29)", fontsize=12)
ax3.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax3.contour(data1.saliency_maps[28,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax3.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax3.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax4 = fig.add_axes([0.75, 0.75, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tp_99_245_QVAPOR5.nc')

ax4.set_title("d) q$_{w}$ 5 km (Neuron 32)", fontsize=12)
ax4.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax4.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax4.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax4.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------
############## NEXT SET
# %--------------------------------------------------------

ax5 = fig.add_axes([0.0, 0.5, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fp_152_EU3.nc')

ax5.set_title("e) u 3 km (Neuron 10)", fontsize=12)
ax5.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax5.contour(data1.saliency_maps[9,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax5.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax5.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

ax5.set_ylabel("False Alarm", fontsize=12)

# %--------------------------------------------------------

ax6 = fig.add_axes([0.25, 0.5, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fp_152_EV3.nc')

ax6.set_title("f) v 3 km (Neuron 32)", fontsize=12)
ax6.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax6.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax6.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax6.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax7 = fig.add_axes([0.5, 0.5, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fp_152_QVAPOR1.nc')

ax7.set_title("g) q$_{w}$ 1 km (Neuron 32)", fontsize=12)
ax7.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax7.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax7.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax7.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax8 = fig.add_axes([0.75, 0.5, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fp_152_QVAPOR5.nc')

ax8.set_title("h) q$_{w}$ 5 km (Neuron 10)", fontsize=12)
ax8.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax8.contour(data1.saliency_maps[9,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax8.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax8.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------
############## NEXT SET
# %--------------------------------------------------------

ax9 = fig.add_axes([0.0, 0.25, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fn_113_EU3.nc')

ax9.set_title("i) u 3 km (Neuron 17)", fontsize=12)
ax9.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax9.contour(data1.saliency_maps[16,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax9.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax9.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

ax9.set_ylabel("Miss", fontsize=12)

# %--------------------------------------------------------

ax10 = fig.add_axes([0.25, 0.25, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fn_113_EV3.nc')

ax10.set_title("j) v 3 km (Neuron 32)", fontsize=12)
ax10.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax10.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax10.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax10.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax11 = fig.add_axes([0.5, 0.25, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fn_113_QVAPOR1.nc')

ax11.set_title("k) q$_{w}$ 1 km (Neuron 32)", fontsize=12)
ax11.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax11.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax11.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax11.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax12 = fig.add_axes([0.75, 0.25, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fn_113_QVAPOR5.nc')

ax12.set_title("l) q$_{w}$ 5 km (Neuron 28)", fontsize=12)
ax12.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax12.contour(data1.saliency_maps[27,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax12.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax12.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------
############## NEXT SET
# %--------------------------------------------------------

ax13 = fig.add_axes([0.0, 0., 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tn_45_EU3.nc')

ax13.set_title("m) u 3 km (Neuron 17)", fontsize=12)
ax13.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax13.contour(data1.saliency_maps[16,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax13.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax13.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

ax13.set_ylabel("True Negative", fontsize=12)

# %--------------------------------------------------------

ax14 = fig.add_axes([0.25, 0., 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tn_45_EV3.nc')

ax14.set_title("n) v 3 km (Neuron 2)", fontsize=12)
ax14.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax14.contour(data1.saliency_maps[1,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax14.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax14.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax15 = fig.add_axes([0.5, 0., 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tn_45_QVAPOR1.nc')

ax15.set_title("o) q$_{w}$ 1 km (Neuron 2)", fontsize=12)
ax15.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax15.contour(data1.saliency_maps[1,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax15.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax15.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax16 = fig.add_axes([0.75, 0., 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tn_45_QVAPOR5.nc')

ax16.set_title("p) q$_{w}$ 5 km (Neuron 2)", fontsize=12)
ax16.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax16.contour(data1.saliency_maps[1,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax16.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax16.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

cbar_ax = fig.add_axes([0.025, -0.02, 0.45, 0.0115])
tickss = [0,20,40,60,80]
cbar = fig.colorbar(cs_t, ticks=tickss, cax=cbar_ax, orientation="horizontal", extend='both')
cbar.ax.set_xticklabels(['0','20','40','60','80'])
cbar.ax.tick_params(labelsize=10)
cbar.set_label('Reflectivity', fontsize=12)

cbar_ax = fig.add_axes([0.525, -0.02, 0.45, 0.0115])
tickss = [-2.5,-1.5,0,1.5,2.5]
cbar = fig.colorbar(cs, ticks=tickss, cax=cbar_ax, orientation="horizontal", extend='both')
cbar.ax.set_xticklabels([-2,-1,0,1,2])
cbar.ax.tick_params(labelsize=10)
cbar.set_label('Gradients', fontsize=12)

# %--------------------------------------------------------

plt.savefig(f"{figsave_path}/journal_fig10.png", bbox_inches='tight', dpi=500)
plt.show()

# %--------------------------------------------------------

# %%
# %--------------------------------------------------------

fig = plt.figure(figsize=(9.,10.))

# %--------------------------------------------------------

ax1 = fig.add_axes([0.0, 0.75, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tp_99_245_EU3.nc')

ax1.set_title("a) u 3 km (Neuron 21)", fontsize=12)
ax1.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax1.contour(data1.saliency_maps[20,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax1.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax1.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

ax1.set_ylabel("Hit", fontsize=12)

# %--------------------------------------------------------

ax2 = fig.add_axes([0.25, 0.75, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tp_99_245_EV3.nc')

ax2.set_title("b) v 3 km (Neuron 15)", fontsize=12)
ax2.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax2.contour(data1.saliency_maps[14,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax2.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax2.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax3 = fig.add_axes([0.5, 0.75, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tp_99_245_QVAPOR1.nc')

ax3.set_title("c) q$_{w}$ 1 km (Neuron 29)", fontsize=12)
ax3.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax3.contour(data1.saliency_maps[28,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax3.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax3.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax4 = fig.add_axes([0.75, 0.75, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tp_99_245_QVAPOR5.nc')

ax4.set_title("d) q$_{w}$ 5 km (Neuron 32)", fontsize=12)
ax4.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax4.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax4.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax4.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------
############## NEXT SET
# %--------------------------------------------------------

ax5 = fig.add_axes([0.0, 0.5, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fp_152_EU3.nc')

ax5.set_title("e) u 3 km (Neuron 10)", fontsize=12)
ax5.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax5.contour(data1.saliency_maps[9,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax5.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax5.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

ax5.set_ylabel("False Alarm", fontsize=12)

# %--------------------------------------------------------

ax6 = fig.add_axes([0.25, 0.5, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fp_152_EV3.nc')

ax6.set_title("f) v 3 km (Neuron 32)", fontsize=12)
ax6.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax6.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax6.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax6.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax7 = fig.add_axes([0.5, 0.5, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fp_152_QVAPOR1.nc')

ax7.set_title("g) q$_{w}$ 1 km (Neuron 32)", fontsize=12)
ax7.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax7.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax7.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax7.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax8 = fig.add_axes([0.75, 0.5, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fp_152_QVAPOR5.nc')

ax8.set_title("h) q$_{w}$ 5 km (Neuron 10)", fontsize=12)
ax8.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax8.contour(data1.saliency_maps[9,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax8.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax8.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------
############## NEXT SET
# %--------------------------------------------------------

ax9 = fig.add_axes([0.0, 0.25, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fn_113_EU3.nc')

ax9.set_title("i) u 3 km (Neuron 17)", fontsize=12)
ax9.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax9.contour(data1.saliency_maps[16,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax9.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax9.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

ax9.set_ylabel("Miss", fontsize=12)

# %--------------------------------------------------------

ax10 = fig.add_axes([0.25, 0.25, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fn_113_EV3.nc')

ax10.set_title("j) v 3 km (Neuron 32)", fontsize=12)
ax10.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax10.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax10.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax10.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax11 = fig.add_axes([0.5, 0.25, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fn_113_QVAPOR1.nc')

ax11.set_title("k) q$_{w}$ 1 km (Neuron 32)", fontsize=12)
ax11.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax11.contour(data1.saliency_maps[31,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax11.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax11.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax12 = fig.add_axes([0.75, 0.25, 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fn_113_QVAPOR5.nc')

ax12.set_title("l) q$_{w}$ 5 km (Neuron 28)", fontsize=12)
ax12.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax12.contour(data1.saliency_maps[27,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax12.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax12.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------
############## NEXT SET
# %--------------------------------------------------------

ax13 = fig.add_axes([0.0, 0., 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tn_45_EU3.nc')

ax13.set_title("m) u 3 km (Neuron 17)", fontsize=12)
ax13.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax13.contour(data1.saliency_maps[16,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax13.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax13.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

ax13.set_ylabel("True Negative", fontsize=12)

# %--------------------------------------------------------

ax14 = fig.add_axes([0.25, 0., 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tn_45_EV3.nc')

ax14.set_title("n) v 3 km (Neuron 2)", fontsize=12)
ax14.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax14.contour(data1.saliency_maps[1,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax14.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax14.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax15 = fig.add_axes([0.5, 0., 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tn_45_QVAPOR1.nc')

ax15.set_title("o) q$_{w}$ 1 km (Neuron 2)", fontsize=12)
ax15.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax15.contour(data1.saliency_maps[1,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax15.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax15.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

ax16 = fig.add_axes([0.75, 0., 0.25, 0.22])

data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_tn_45_QVAPOR5.nc')

ax16.set_title("p) q$_{w}$ 5 km (Neuron 2)", fontsize=12)
ax16.contourf(data1.dbz, cmap=cmap, levels=levels, alpha=0.2)
ax16.contour(data1.saliency_maps[1,:,:], 
           [-3, -2, -1, 1, 2, 3], vmin=-3, vmax=3, cmap="seismic", linewidths=3.0)
ax16.tick_params(axis='x', which='both', direction='in', bottom=False, top=False, labelbottom=False)
ax16.tick_params(axis='y', which='both', direction='in', left=False, right=False, labelleft=False)

# %--------------------------------------------------------

cbar_ax = fig.add_axes([0.025, -0.02, 0.45, 0.0115])
tickss = [0,20,40,60,80]
cbar = fig.colorbar(cs_t, ticks=tickss, cax=cbar_ax, orientation="horizontal", extend='both')
cbar.ax.set_xticklabels(['0','20','40','60','80'])
cbar.ax.tick_params(labelsize=10)
cbar.set_label('Reflectivity', fontsize=12)

cbar_ax = fig.add_axes([0.525, -0.02, 0.45, 0.0115])
tickss = [-2.5,-1.5,0,1.5,2.5]
cbar = fig.colorbar(cs, ticks=tickss, cax=cbar_ax, orientation="horizontal", extend='both')
cbar.ax.set_xticklabels([-2,-1,0,1,2])
cbar.ax.tick_params(labelsize=10)
cbar.set_label('Gradients', fontsize=12)

# %--------------------------------------------------------

plt.savefig(f"{figsave_path}/journal_fig10.pdf", bbox_inches='tight', dpi=500)
plt.show()

# %--------------------------------------------------------

# %%
#exec(open('/glade/u/home/molina/python_scripts/deep-conus/deep-conus/09_dlmodel_interpretor.py').read())

#test = InterpretDLModel(climate='future', variable='EU3', 
#                        dist_directory=f'{future_dl_preprocess}', 
#                        model_directory=f'{current_dl_models}', 
#                        model_num=25, 
#                        comp_directory=f'{future_dl_models}', 
#                        mask=False,  mask_train=False, unbalanced=True, isotonic=False,
#                        random_choice=1, outliers=False)

#data1=xr.open_dataset(f'{future_dl_models}/saliency_nomask_model25_random1_fp_152_EU3.nc')
#test.auto_saliency(data1)

#data1=xr.open_dataset(f'{future_dl_models}/inputgrad_nomask_model25_random1_fp_152_EU3.nc')
#test.auto_saliency(data1)
