# %% [markdown]
# ### Creation of data for Figure 12 and Figure 13 (Molina, Gagne, and Prein; under review)
#
# Imports

# %%
exec(open('/glade/u/home/molina/python_scripts/deep-conus/deep-conus/09_dlmodel_interpretor.py').read())

# %%
# import local paths
from configpaths import current_dl_preprocess, future_dl_preprocess
from configpaths import current_dl_models, future_dl_models, dlproj_main

# %%
which_model = 25

# %%
test = InterpretDLModel(climate='current', variable='EU3', 
                        dist_directory=f'{current_dl_preprocess}', 
                        model_directory=f'{current_dl_models}', 
                        model_num=which_model, 
                        comp_directory=f'{current_dl_models}', 
                        mask=False,  mask_train=False, unbalanced=True, isotonic=False,
                        random_choice=1)

test.extract_variable_mean_and_std()
test.extract_dbz_mean_and_std()
test.extract_eu_mean_and_std()
test.extract_ev_mean_and_std()
test.extract_uh25_mean_and_std()
test.extract_uh03_mean_and_std()
model_loaded=test.extract_model()
testdata=test.extract_variable_and_dbz()

rand1_sum_tpc = xr.where(
    (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand1_sum_fnc = xr.where(
    (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand1_max_tpc = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand1_max_fpc = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand1_max_fnc = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
tp_hist1c = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fp_hist1c = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fn_hist1c = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
tn_hist1c = (testdata['tn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
testdata = None
test = None


test = InterpretDLModel(climate='current', variable='EU3', 
                        dist_directory=f'{current_dl_preprocess}', 
                        model_directory=f'{current_dl_models}', 
                        model_num=which_model, 
                        comp_directory=f'{current_dl_models}', 
                        mask=False,  mask_train=False, unbalanced=True, isotonic=False,
                        random_choice=2)

test.extract_variable_mean_and_std()
test.extract_dbz_mean_and_std()
test.extract_eu_mean_and_std()
test.extract_ev_mean_and_std()
test.extract_uh25_mean_and_std()
test.extract_uh03_mean_and_std()
model_loaded=test.extract_model()
testdata=test.extract_variable_and_dbz()

rand2_sum_tpc = xr.where(
    (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand2_sum_fnc = xr.where(
    (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand2_max_tpc = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand2_max_fpc = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand2_max_fnc = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
tp_hist2c = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fp_hist2c = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fn_hist2c = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
tn_hist2c = (testdata['tn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
testdata = None
test = None


test = InterpretDLModel(climate='current', variable='EU3', 
                        dist_directory=f'{current_dl_preprocess}', 
                        model_directory=f'{current_dl_models}', 
                        model_num=which_model, 
                        comp_directory=f'{current_dl_models}', 
                        mask=False,  mask_train=False, unbalanced=True, isotonic=False,
                        random_choice=3)

test.extract_variable_mean_and_std()
test.extract_dbz_mean_and_std()
test.extract_eu_mean_and_std()
test.extract_ev_mean_and_std()
test.extract_uh25_mean_and_std()
test.extract_uh03_mean_and_std()
model_loaded=test.extract_model()
testdata=test.extract_variable_and_dbz()

rand3_sum_tpc = xr.where(
    (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand3_sum_fnc = xr.where(
    (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand3_max_tpc = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand3_max_fpc = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand3_max_fnc = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
tp_hist3c = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fp_hist3c = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fn_hist3c = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
tn_hist3c = (testdata['tn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
testdata = None
test = None


test = InterpretDLModel(climate='current', variable='EU3', 
                        dist_directory=f'{current_dl_preprocess}', 
                        model_directory=f'{current_dl_models}', 
                        model_num=which_model, 
                        comp_directory=f'{current_dl_models}', 
                        mask=False,  mask_train=False, unbalanced=True, isotonic=False,
                        random_choice=4)

test.extract_variable_mean_and_std()
test.extract_dbz_mean_and_std()
test.extract_eu_mean_and_std()
test.extract_ev_mean_and_std()
test.extract_uh25_mean_and_std()
test.extract_uh03_mean_and_std()
model_loaded=test.extract_model()
testdata=test.extract_variable_and_dbz()

rand4_sum_tpc = xr.where(
    (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand4_sum_fnc = xr.where(
    (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand4_max_tpc = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand4_max_fpc = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand4_max_fnc = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
tp_hist4c = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fp_hist4c = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fn_hist4c = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
tn_hist4c = (testdata['tn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
testdata = None
test = None


test = InterpretDLModel(climate='current', variable='EU3', 
                        dist_directory=f'{current_dl_preprocess}', 
                        model_directory=f'{current_dl_models}', 
                        model_num=which_model, 
                        comp_directory=f'{current_dl_models}', 
                        mask=False,  mask_train=False, unbalanced=True, isotonic=False,
                        random_choice=5)

test.extract_variable_mean_and_std()
test.extract_dbz_mean_and_std()
test.extract_eu_mean_and_std()
test.extract_ev_mean_and_std()
test.extract_uh25_mean_and_std()
test.extract_uh03_mean_and_std()
model_loaded=test.extract_model()
testdata=test.extract_variable_and_dbz()

rand5_sum_tpc = xr.where(
    (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand5_sum_fnc = xr.where(
    (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand5_max_tpc = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand5_max_fpc = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand5_max_fnc = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
tp_hist5c = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fp_hist5c = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fn_hist5c = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
tn_hist5c = (testdata['tn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
testdata = None
test = None
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        16032
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 48)        38448
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 48)        192
# _________________________________________________________________
# spatial_dropout2d_2 (Spatial (None, 16, 16, 48)        0
# ...

# %%
test = InterpretDLModel(climate='future', variable='EU3', 
                        dist_directory=f'{future_dl_preprocess}', 
                        model_directory=f'{current_dl_models}', 
                        model_num=which_model, 
                        comp_directory=f'{future_dl_models}', 
                        mask=False,  mask_train=False, unbalanced=True, isotonic=False,
                        random_choice=1)

test.extract_variable_mean_and_std()
test.extract_dbz_mean_and_std()
test.extract_eu_mean_and_std()
test.extract_ev_mean_and_std()
test.extract_uh25_mean_and_std()
test.extract_uh03_mean_and_std()
model_loaded=test.extract_model()
testdata=test.extract_variable_and_dbz()

rand1_sum_tp = xr.where((testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand1_sum_fn = xr.where((testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand1_max_tp = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand1_max_fp = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand1_max_fn = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
tp_hist1 = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fp_hist1 = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fn_hist1 = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
tn_hist1 = (testdata['tn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
testdata = None
test = None


test = InterpretDLModel(climate='future', variable='EU3', 
                        dist_directory=f'{future_dl_preprocess}', 
                        model_directory=f'{current_dl_models}', 
                        model_num=which_model, 
                        comp_directory=f'{future_dl_models}', 
                        mask=False,  mask_train=False, unbalanced=True, isotonic=False,
                        random_choice=2)

test.extract_variable_mean_and_std()
test.extract_dbz_mean_and_std()
test.extract_eu_mean_and_std()
test.extract_ev_mean_and_std()
test.extract_uh25_mean_and_std()
test.extract_uh03_mean_and_std()
model_loaded=test.extract_model()
testdata=test.extract_variable_and_dbz()

rand2_sum_tp = xr.where((testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand2_sum_fn = xr.where((testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand2_max_tp = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand2_max_fp = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand2_max_fn = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
tp_hist2 = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fp_hist2 = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fn_hist2 = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
tn_hist2 = (testdata['tn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
testdata = None
test = None


test = InterpretDLModel(climate='future', variable='EU3', 
                        dist_directory=f'{future_dl_preprocess}', 
                        model_directory=f'{current_dl_models}', 
                        model_num=which_model, 
                        comp_directory=f'{future_dl_models}', 
                        mask=False,  mask_train=False, unbalanced=True, isotonic=False,
                        random_choice=3)

test.extract_variable_mean_and_std()
test.extract_dbz_mean_and_std()
test.extract_eu_mean_and_std()
test.extract_ev_mean_and_std()
test.extract_uh25_mean_and_std()
test.extract_uh03_mean_and_std()
model_loaded=test.extract_model()
testdata=test.extract_variable_and_dbz()

rand3_sum_tp = xr.where((testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand3_sum_fn = xr.where((testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand3_max_tp = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand3_max_fp = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand3_max_fn = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
tp_hist3 = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fp_hist3 = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fn_hist3 = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
tn_hist3 = (testdata['tn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
testdata = None
test = None


test = InterpretDLModel(climate='future', variable='EU3', 
                        dist_directory=f'{future_dl_preprocess}', 
                        model_directory=f'{current_dl_models}', 
                        model_num=which_model, 
                        comp_directory=f'{future_dl_models}', 
                        mask=False,  mask_train=False, unbalanced=True, isotonic=False,
                        random_choice=4)

test.extract_variable_mean_and_std()
test.extract_dbz_mean_and_std()
test.extract_eu_mean_and_std()
test.extract_ev_mean_and_std()
test.extract_uh25_mean_and_std()
test.extract_uh03_mean_and_std()
model_loaded=test.extract_model()
testdata=test.extract_variable_and_dbz()

rand4_sum_tp = xr.where((testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand4_sum_fn = xr.where((testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand4_max_tp = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand4_max_fp = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand4_max_fn = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
tp_hist4 = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fp_hist4 = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fn_hist4 = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
tn_hist4 = (testdata['tn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
testdata = None
test = None


test = InterpretDLModel(climate='future', variable='EU3', 
                        dist_directory=f'{future_dl_preprocess}', 
                        model_directory=f'{current_dl_models}', 
                        model_num=which_model, 
                        comp_directory=f'{future_dl_models}', 
                        mask=False,  mask_train=False, unbalanced=True, isotonic=False,
                        random_choice=5)

test.extract_variable_mean_and_std()
test.extract_dbz_mean_and_std()
test.extract_eu_mean_and_std()
test.extract_ev_mean_and_std()
test.extract_uh25_mean_and_std()
test.extract_uh03_mean_and_std()
model_loaded=test.extract_model()
testdata=test.extract_variable_and_dbz()

rand5_sum_tp = xr.where((testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand5_sum_fn = xr.where((testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand5_max_tp = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand5_max_fp = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand5_max_fn = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
tp_hist5 = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fp_hist5 = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fn_hist5 = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
tn_hist5 = (testdata['tn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
testdata = None
test = None
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        16032
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 48)        38448
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 48)        192
# _________________________________________________________________
# spatial_dropout2d_2 (Spatial (None, 16, 16, 48)        0
# ...

# %%
test = InterpretDLModel(climate='future', variable='EU3', 
                        dist_directory=f'{future_dl_preprocess}', 
                        model_directory=f'{current_dl_models}', 
                        model_num=which_model, 
                        comp_directory=f'{future_dl_models}', 
                        mask=False,  mask_train=False, unbalanced=True, isotonic=False,
                        random_choice=1, outliers=True)

test.extract_variable_mean_and_std()
test.extract_dbz_mean_and_std()
test.extract_eu_mean_and_std()
test.extract_ev_mean_and_std()
test.extract_uh25_mean_and_std()
test.extract_uh03_mean_and_std()
model_loaded=test.extract_model()
testdata=test.extract_variable_and_dbz()

rand1_sum_tpo = xr.where((testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand1_sum_fno = xr.where((testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean)>=75.,
                         1.,0).sum(axis=0)
rand1_max_tpo = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand1_max_fpo = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
rand1_max_fno = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=0)
tp_hist1o = (testdata['tp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fp_hist1o = (testdata['fp'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
fn_hist1o = (testdata['fn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
tn_hist1o = (testdata['tn'][:, :, :, test.extract_uh25_index(testdata)] * test.uh25_std + test.uh25_mean).max(axis=1).max(axis=1)
testdata = None
test = None
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_1 (Conv2D)            (None, 32, 32, 32)        16032
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 32, 32, 32)        128
# _________________________________________________________________
# spatial_dropout2d_1 (Spatial (None, 32, 32, 32)        0
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 16, 16, 32)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 16, 16, 48)        38448
# _________________________________________________________________
# batch_normalization_2 (Batch (None, 16, 16, 48)        192
# _________________________________________________________________
# spatial_dropout2d_2 (Spatial (None, 16, 16, 48)        0
# ...

# %%
data_to_save = xr.Dataset({

                'tp_c': (['a'], xr.concat([tp_hist1c,tp_hist2c,tp_hist3c,tp_hist4c,tp_hist5c], dim='a').values),
                'tp_f': (['aa'], xr.concat([tp_hist1,tp_hist2,tp_hist3,tp_hist4,tp_hist5], dim='a').values),
                'tp_o': (['aaa'], tp_hist1o.values),
    
                'fp_c': (['c'], xr.concat([fp_hist1c,fp_hist2c,fp_hist3c,fp_hist4c,fp_hist5c], dim='c').values),
                'fp_f': (['cc'], xr.concat([fp_hist1,fp_hist2,fp_hist3,fp_hist4,fp_hist5], dim='c').values),
                'fp_o': (['ccc'], fp_hist1o.values),

                'fn_c': (['e'], xr.concat([fn_hist1c,fn_hist2c,fn_hist3c,fn_hist4c,fn_hist5c], dim='e').values),
                'fn_f': (['ee'], xr.concat([fn_hist1,fn_hist2,fn_hist3,fn_hist4,fn_hist5], dim='e').values),
                'fn_o': (['eee'], fn_hist1o.values),
    
                'tn_c': (['g'], xr.concat([tn_hist1c,tn_hist2c,tn_hist3c,tn_hist4c,tn_hist5c], dim='g').values),
                'tn_f': (['gg'], xr.concat([tn_hist1,tn_hist2,tn_hist3,tn_hist4,tn_hist5], dim='g').values),
                'tn_o': (['ggg'], tn_hist1o.values),
})

# %%
data_to_save
# Out:
# <xarray.Dataset>
# Dimensions:  (a: 9089, aa: 10984, aaa: 601, c: 1633, cc: 3420, ccc: 280, e: 2250, ee: 1954, eee: 34, g: 441270, gg: 440109, ggg: 3652)
# Dimensions without coordinates: a, aa, aaa, c, cc, ccc, e, ee, eee, g, gg, ggg
# Data variables:
#     tp_c     (a) float32 166.1 116.4 112.5 200.2 ... 94.59 83.91 351.0 92.08
#     tp_f     (aa) float32 203.4 78.3 95.3 104.0 ... 84.94 160.7 85.87 374.9
#     tp_o     (aaa) float32 203.4 82.26 366.5 108.1 ... 218.7 373.9 195.2 375.0
#     fp_c     (c) float32 58.19 68.71 74.43 73.77 ... 54.84 67.18 68.38 61.51
#     fp_f     (cc) float32 71.05 66.96 66.47 68.54 ... 54.84 51.3 22.94 65.06
#     fp_o     (ccc) float32 50.42 64.75 23.88 67.99 ... 69.86 50.32 54.79 35.48
#     fn_c     (e) float32 82.27 88.38 90.28 101.2 ... 104.8 77.86 88.1 79.39
#     fn_f     (ee) float32 108.2 114.5 81.62 92.19 ... 77.15 79.28 84.56 171.9
#     fn_o     (eee) float32 110.4 76.91 129.3 115.8 ... 78.87 75.46 77.42 76.91
# ...

# %%
data_to_save.to_netcdf(f'{dlproj_main}/model{which_model}_fig12_data.nc')

# %%
data_to_save2 = xr.Dataset({

        'tp_c': (['x','y'], ((rand1_sum_tpc+rand2_sum_tpc+rand3_sum_tpc+rand4_sum_tpc+rand5_sum_tpc)/np.nanmax(
            rand1_sum_tpc+rand2_sum_tpc+rand3_sum_tpc+rand4_sum_tpc+rand5_sum_tpc)).astype(float).values),
        'fn_c': (['x','y'], ((rand1_sum_fnc+rand2_sum_fnc+rand3_sum_fnc+rand4_sum_fnc+rand5_sum_fnc)/np.nanmax(
            rand1_sum_fnc+rand2_sum_fnc+rand3_sum_fnc+rand4_sum_fnc+rand5_sum_fnc)).astype(float).values),
        'tp_f': (['x','y'], ((rand1_sum_tp+rand2_sum_tp+rand3_sum_tp+rand4_sum_tp+rand5_sum_tp)/np.nanmax(
            rand1_sum_tp+rand2_sum_tp+rand3_sum_tp+rand4_sum_tp+rand5_sum_tp)).astype(float).values),
        'fn_f': (['x','y'], ((rand1_sum_fn+rand2_sum_fn+rand3_sum_fn+rand4_sum_fn+rand5_sum_fn)/np.nanmax(
            rand1_sum_fn+rand2_sum_fn+rand3_sum_fn+rand4_sum_fn+rand5_sum_fn)).astype(float).values),

})

# %%
data_to_save2
# Out:
# <xarray.Dataset>
# Dimensions:  (x: 32, y: 32)
# Dimensions without coordinates: x, y
# Data variables:
#     tp_c     (x, y) float64 0.1802 0.1982 0.3063 0.2432 ... 0.1802 0.1441 0.1171
#     fn_c     (x, y) float64 0.8333 0.375 0.4583 0.3333 ... 0.25 0.25 0.2917
#     tp_f     (x, y) float64 0.1452 0.3065 0.2661 0.2419 ... 0.1774 0.1452 0.1694
#     fn_f     (x, y) float64 0.48 0.24 0.2 0.24 0.28 ... 0.2 0.4 0.28 0.12 0.28

# %%
data_to_save2.to_netcdf(f'{dlproj_main}/model{which_model}_fig13_data.nc')
